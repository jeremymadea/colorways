# %%
# %run 'init_notebook.py'
from colorways.spectra import aesthetic, rainbow
import matplotlib.pyplot as plt

# %%
show_color(rgb2hex(aesthetic.wavelen2rgb(490)))
# Out:
# Canvas(height=100, width=100)

# %%
aesthetic_spectrum = [ aesthetic.wavelen2rgb(nm) for nm in range(400,700) ]

# %%
show_palette(rgb2hsl(aesthetic_spectrum))
# Out:
# Canvas(height=200, width=720)

# %%
plt.plot([c[0] for c in aesthetic_spectrum], color='r')
plt.plot([c[1] for c in aesthetic_spectrum], color='g')
plt.plot([c[2] for c in aesthetic_spectrum], color='b')

# %%
rainbow_spectrum = [ rainbow.wavelen2rgb(nm) for nm in range(400, 700) ]
show_palette(rgb2hsl(rainbow_spectrum))
# Out:
# Canvas(height=200, width=720)

# %%
plt.plot([c[0] for c in rainbow_spectrum], color='r')
plt.plot([c[1] for c in rainbow_spectrum], color='g')
plt.plot([c[2] for c in rainbow_spectrum], color='b')

# %%
from colorways.spectra import cie64ten, cie06ten, cie06two, cie06twofine

# %%
accuratish01 = [cie64ten.wavelen2rgb(nm) for nm in range(390, 800)]
accuratish02 = [cie06ten.wavelen2rgb(nm) for nm in range(390, 800)]
accuratish03 = [cie06two.wavelen2rgb(nm) for nm in range(390, 800)]

# %%
plt.plot([c[0] for c in accuratish01], color='r')
plt.plot([c[1] for c in accuratish01], color='g')
plt.plot([c[2] for c in accuratish01], color='b')

# %%
plt.plot([c[0] for c in accuratish02], color='r')
plt.plot([c[1] for c in accuratish02], color='g')
plt.plot([c[2] for c in accuratish02], color='b')

# %%
plt.plot([c[0] for c in accuratish03], color='r')
plt.plot([c[1] for c in accuratish03], color='g')
plt.plot([c[2] for c in accuratish03], color='b')

# %%
show_palette(rgb2hsl(accuratish01))
# Out:
# Canvas(height=200, width=720)

# %%
show_palette(rgb2hsl(accuratish02))
# Out:
# Canvas(height=200, width=720)

# %%
show_palette(rgb2hsl(accuratish03))
# Out:
# Canvas(height=200, width=720)

# %%
hirez = [cie06twofine.wavelen2rgb(nm/10) for nm in range(3900, 8000)]
print(len(hirez))
show_palette(rgb2hsl(hirez))
# Out:
# 4100
# Canvas(height=200, width=720)

# %%
show_palette(rgb2hsl([cie06two.wavelen2rgb(nm) for nm in range(440,500) ]))
# Out:
# Canvas(height=200, width=720)

# %%
from colorways.blend import * 
show_palette(rgb2hsl(
    [ cie06twofine.wavelen2rgb(nm/10.0) for nm in range(4400,5000)]))
# Out:
# Canvas(height=200, width=720)
